# %%
import json data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96}, {'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85}, {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77}, {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62}, {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70}, {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82}) import pandas as pd BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"]) for i in range(0,len(data)): currentitem= data[i] BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]] for ind,row in BMI.iterrows(): BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2) BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI] BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI] BMI
# Out:
#   File "<ipython-input-1-272916586a20>", line 1
#     import json data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96}, {'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85}, {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77}, {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62}, {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70}, {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82}) import pandas as pd BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"]) for i in range(0,len(data)): currentitem= data[i] BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]] for ind,row in BMI.iterrows(): BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2) BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI] BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI] BMI
#                    ^
# SyntaxError: invalid syntax

# %%
import json 
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},  {'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},  {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},  {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},  {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},  {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})
import pandas as pd 
BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])
for i in range(0,len(data)):     
currentitem= data[i]     
BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]] 
for ind.row in BMI.iterrows():     
BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2) 
BMI['BMI Category'] =["Underweight" if i&lt;=18.4 else "Normal weight" if i>=18.5 and i&lt;=24.9 else "Overweight" if i>=25 and i&lt;=29.9 else "Moderately obese" if i>=30 and i&lt;=34.9 else "Severely obese" if i>=35 and i&lt;=39.9 else "Very severely obese" for i in BMI.BMI] 
BMI['Health Risk'] =["Malnutrition risk" if i&lt;=18.4 else "Low risk" if i>=18.5 and i&lt;=24.9 else "Enhanced risk" if i>=25 and i&lt;=29.9 else "Medium risk" if i>=30 and i&lt;=34.9 else "High risk" if i>=35 and i&lt;=39.9 else "Very high risk" for i in BMI.BMI] 
BMI
# Out:
#   File "<ipython-input-4-a8809e3a2e53>", line 6
#     currentitem= data[i]
#               ^
# IndentationError: expected an indented block

# %%
# BMI Table(Question 1) #
import json
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
 {'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},
 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})
import pandas as pd
BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])
for i in range(0,len(data)):
    currentitem= data[i]
    BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():
    BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]
BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]
BMI
# Out:
#    Gender HeightCm WeightKg        BMI      BMI Category    Health Risk
# 0    Male      171       96  32.830615  Moderately obese    Medium risk
# 1    Male      161       85  32.791945  Moderately obese    Medium risk
# 2    Male      180       77  23.765432     Normal weight       Low risk
# 3  Female      166       62  22.499637     Normal weight       Low risk
# 4  Female      150       70  31.111111  Moderately obese    Medium risk
# 5  Female      167       82  29.402273        Overweight  Enhanced risk

# %%
import json
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},
 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

# %%
import json
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},
 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})
 import pandas as pd
 BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])
for i in range(0,len(data)):
    currentitem= data[i]
    BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():
# Out:
#   File "<ipython-input-7-efd1e53ffffa>", line 8
#     import pandas as pd
#     ^
# IndentationError: unexpected indent

# %%
import json
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},
 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})
 import pandas as pd
 BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])
for i in range(0,len(data)):
    currentitem= data[i]
BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():
    BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
# Out:
#   File "<ipython-input-8-779c6ed742a3>", line 8
#     import pandas as pd
#     ^
# IndentationError: unexpected indent

# %%
import json
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},
 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

 import pandas as pd
 BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])
for i in range(0,len(data)):
    currentitem= data[i]
BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():
    BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
# Out:
#   File "<ipython-input-9-9bfe84d96390>", line 9
#     import pandas as pd
#     ^
# IndentationError: unexpected indent

# %%
import json
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},
 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

 import pandas as pd
    
BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])
for i in range(0,len(data)):
    currentitem= data[i]
BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():
    BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
# Out:
#   File "<ipython-input-10-768608bdd113>", line 9
#     import pandas as pd
#     ^
# IndentationError: unexpected indent

# %%
# BMI Table(Question 1) #
import json
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
 {'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},
 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})
data
# Out:
# ({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
#  {'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},
#  {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
#  {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
#  {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
#  {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

# %%
import pandas as pd
BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])
for i in range(0,len(data)):
    currentitem= data[i]
    BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():
    BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]
BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]
BMI
# Out:
#    Gender HeightCm WeightKg        BMI      BMI Category    Health Risk
# 0    Male      171       96  32.830615  Moderately obese    Medium risk
# 1    Male      161       85  32.791945  Moderately obese    Medium risk
# 2    Male      180       77  23.765432     Normal weight       Low risk
# 3  Female      166       62  22.499637     Normal weight       Low risk
# 4  Female      150       70  31.111111  Moderately obese    Medium risk
# 5  Female      167       82  29.402273        Overweight  Enhanced risk

# %%
import json
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},
 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})
 data
import pandas as pd
BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])
for i in range(0,len(data)):
    currentitem= data[i]
    BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():
    BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]
BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]
BMI
# Out:
#   File "<ipython-input-13-1762530f100c>", line 8
#     data
#     ^
# IndentationError: unexpected indent

# %%
import json
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},
 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd
BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])
for i in range(0,len(data)):
    currentitem= data[i]
    BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():
    BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]
BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]
BMI
# Out:
#    Gender HeightCm WeightKg        BMI      BMI Category    Health Risk
# 0    Male      171       96  32.830615  Moderately obese    Medium risk
# 1    Male      161       85  32.791945  Moderately obese    Medium risk
# 2    Male      180       77  23.765432     Normal weight       Low risk
# 3  Female      166       62  22.499637     Normal weight       Low risk
# 4  Female      150       70  31.111111  Moderately obese    Medium risk
# 5  Female      167       82  29.402273        Overweight  Enhanced risk

# %%
import json
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},
 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})
 
import pandas as pd
BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])
for i in range(0,len(data)):
    currentitem= data[i]
    BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():
    BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]
BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]
BMI
# Out:
#    Gender HeightCm WeightKg        BMI      BMI Category    Health Risk
# 0    Male      171       96  32.830615  Moderately obese    Medium risk
# 1    Male      161       85  32.791945  Moderately obese    Medium risk
# 2    Male      180       77  23.765432     Normal weight       Low risk
# 3  Female      166       62  22.499637     Normal weight       Low risk
# 4  Female      150       70  31.111111  Moderately obese    Medium risk
# 5  Female      167       82  29.402273        Overweight  Enhanced risk

# %%
# Total Overweight(Question 2) #
Totaloverweight =list(BMI['BMI Category']).count('Overweight')
Totaloverweight
# Out:
# 1

# %%
# Frequency Table for BMI Category (Additional) #

BMI['BMI Category'].value_counts()
# Out:
# Moderately obese    3
# Normal weight       2
# Overweight          1
# Name: BMI Category, dtype: int64

# %%
import json data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96}, {'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85}, {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77}, {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62}, {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70}, {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"]) for i in range(0,len(data)): currentitem= data[i] BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]] for ind,row in BMI.iterrows(): BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2) BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI] BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI] BMI
# Out:
#   File "<ipython-input-18-4de304293207>", line 1
#     import json data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96}, {'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85}, {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77}, {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62}, {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70}, {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})
#                    ^
# SyntaxError: invalid syntax

# %%
import json
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})
 
 
import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):

    currentitem= data[i]
    
    BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
    
for ind,row in BMI.iterrows():

    BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
    
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#    Gender HeightCm WeightKg        BMI      BMI Category    Health Risk
# 0    Male      171       96  32.830615  Moderately obese    Medium risk
# 1    Male      161       85  32.791945  Moderately obese    Medium risk
# 2    Male      180       77  23.765432     Normal weight       Low risk
# 3  Female      166       62  22.499637     Normal weight       Low risk
# 4  Female      150       70  31.111111  Moderately obese    Medium risk
# 5  Female      167       82  29.402273        Overweight  Enhanced risk

# %%
import json data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):

currentitem= data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():

BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#   File "<ipython-input-20-3d20febb242f>", line 1
#     import json data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
#                    ^
# SyntaxError: invalid syntax

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):

currentitem= data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():

BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#   File "<ipython-input-21-678a129ab88d>", line 21
#     currentitem= data[i]
#               ^
# IndentationError: expected an indented block

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})
 
 
import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):

    currentitem= data[i]
    
    BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
    
for ind,row in BMI.iterrows():

    BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
    
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#    Gender HeightCm WeightKg        BMI      BMI Category    Health Risk
# 0    Male      171       96  32.830615  Moderately obese    Medium risk
# 1    Male      161       85  32.791945  Moderately obese    Medium risk
# 2    Male      180       77  23.765432     Normal weight       Low risk
# 3  Female      166       62  22.499637     Normal weight       Low risk
# 4  Female      150       70  31.111111  Moderately obese    Medium risk
# 5  Female      167       82  29.402273        Overweight  Enhanced risk

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):

currentitem= data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():

BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#   File "<ipython-input-23-678a129ab88d>", line 21
#     currentitem= data[i]
#               ^
# IndentationError: expected an indented block

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):

currentitem= data[i]
BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows():

BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#   File "<ipython-input-24-55656d74dbcf>", line 21
#     currentitem= data[i]
#               ^
# IndentationError: expected an indented block

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):

currentitem= data[i]
BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows():

BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#   File "<ipython-input-25-55656d74dbcf>", line 21
#     currentitem= data[i]
#               ^
# IndentationError: expected an indented block

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})
 
 
import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])


for i in range(0,len(data)):

    currentitem= data[i]     
    BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

    
for ind,row in BMI.iterrows():
    BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
    
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#    Gender HeightCm WeightKg        BMI      BMI Category    Health Risk
# 0    Male      171       96  32.830615  Moderately obese    Medium risk
# 1    Male      161       85  32.791945  Moderately obese    Medium risk
# 2    Male      180       77  23.765432     Normal weight       Low risk
# 3  Female      166       62  22.499637     Normal weight       Low risk
# 4  Female      150       70  31.111111  Moderately obese    Medium risk
# 5  Female      167       82  29.402273        Overweight  Enhanced risk

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):

currentitem= data[i]     
BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
# Out:
#   File "<ipython-input-27-b10d0f4740c1>", line 21
#     currentitem= data[i]
#               ^
# IndentationError: expected an indented block

# %%
mport json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)): currentitem= data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows(): BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
# Out:
#   File "<ipython-input-28-a92b087ccc2b>", line 1
#     mport json
#              ^
# SyntaxError: invalid syntax

# %%
Import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)): currentitem= data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows(): BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
# Out:
#   File "<ipython-input-29-52f3d493990b>", line 1
#     Import json
#               ^
# SyntaxError: invalid syntax

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)): currentitem= data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows(): BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)

# %%
mport json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)): currentitem= data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows(): BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)

BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#   File "<ipython-input-31-ce162e00708a>", line 1
#     mport json
#              ^
# SyntaxError: invalid syntax

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)): currentitem= data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows(): BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)

BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#    Gender HeightCm WeightKg        BMI BMI Category    Health Risk
# 5  Female      167       82  29.402273   Overweight  Enhanced risk

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)): currentitem= data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows(): BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)

BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#    Gender HeightCm WeightKg        BMI BMI Category    Health Risk
# 5  Female      167       82  29.402273   Overweight  Enhanced risk

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)): currentitem= data[i]
BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows(): BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)

BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#    Gender HeightCm WeightKg        BMI BMI Category    Health Risk
# 5  Female      167       82  29.402273   Overweight  Enhanced risk

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)): currentitem= data[i]
BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

# %%
BMI
# Out:
#    Gender HeightCm WeightKg
# 5  Female      167       82

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):           
    currentitem= data[i]
BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

# %%
BMI
# Out:
#    Gender HeightCm WeightKg
# 5  Female      167       82

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):           
    currentitem= data[i]
BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

# %%
BMI
# Out:
#    Gender HeightCm WeightKg
# 5  Female      167       82

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):

currentitem= data[i]
BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows():

BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#   File "<ipython-input-42-55656d74dbcf>", line 21
#     currentitem= data[i]
#               ^
# IndentationError: expected an indented block

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):

currentitem= data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows():

BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)

BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#   File "<ipython-input-43-25080f66d77f>", line 21
#     currentitem= data[i]
#               ^
# IndentationError: expected an indented block

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):

currentitem= data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows():

BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)

BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#   File "<ipython-input-44-25080f66d77f>", line 21
#     currentitem= data[i]
#               ^
# IndentationError: expected an indented block

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):

currentitem = data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows():

BMI.loc[ind,"BMI"] =(row['WeightKg'])/((row['HeightCm']/100)**2)

BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#   File "<ipython-input-45-45affde0bca5>", line 21
#     currentitem = data[i]
#               ^
# IndentationError: expected an indented block

# %%
import json

data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},

{'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},

{'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},

{'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},

{'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},

{'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})

import pandas as pd

BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])

for i in range(0,len(data)):
    
    currentitem = data[i]

BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]

for ind,row in BMI.iterrows():
    
    BMI.loc[ind,"BMI"] =(row['WeightKg'])/((row['HeightCm']/100)**2)

BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]

BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]

BMI
# Out:
#    Gender HeightCm WeightKg        BMI BMI Category    Health Risk
# 5  Female      167       82  29.402273   Overweight  Enhanced risk

# %%
import json
data =({'Gender': 'Male', 'HeightCm': 171, 'WeightKg': 96},
 {'Gender': 'Male', 'HeightCm': 161, 'WeightKg': 85},
 {'Gender': 'Male', 'HeightCm': 180, 'WeightKg': 77},
 {'Gender': 'Female', 'HeightCm': 166, 'WeightKg': 62},
 {'Gender': 'Female', 'HeightCm': 150, 'WeightKg': 70},
 {'Gender': 'Female', 'HeightCm': 167, 'WeightKg': 82})
data
import pandas as pd
BMI=pd.DataFrame(columns=["Gender","HeightCm","WeightKg"])
for i in range(0,len(data)):
    currentitem= data[i]
    BMI.loc[i]=[data[i]["Gender"],data[i]["HeightCm"],data[i]["WeightKg"]]
for ind,row in BMI.iterrows():
    BMI.loc[ind,"BMI"]=(row['WeightKg'])/((row['HeightCm']/100)**2)
BMI['BMI Category'] =["Underweight" if i<=18.4 else "Normal weight" if i>=18.5 and i<=24.9 else "Overweight" if i>=25 and i<=29.9 else "Moderately obese" if i>=30 and i<=34.9 else "Severely obese" if i>=35 and i<=39.9 else "Very severely obese" for i in BMI.BMI]
BMI['Health Risk'] =["Malnutrition risk" if i<=18.4 else "Low risk" if i>=18.5 and i<=24.9 else "Enhanced risk" if i>=25 and i<=29.9 else "Medium risk" if i>=30 and i<=34.9 else "High risk" if i>=35 and i<=39.9 else "Very high risk" for i in BMI.BMI]
BMI
# Out:
#    Gender HeightCm WeightKg        BMI      BMI Category    Health Risk
# 0    Male      171       96  32.830615  Moderately obese    Medium risk
# 1    Male      161       85  32.791945  Moderately obese    Medium risk
# 2    Male      180       77  23.765432     Normal weight       Low risk
# 3  Female      166       62  22.499637     Normal weight       Low risk
# 4  Female      150       70  31.111111  Moderately obese    Medium risk
# 5  Female      167       82  29.402273        Overweight  Enhanced risk
